# %%
import pandas as pd
from datasets import Dataset
import torch
import json
import os

# 파일 불러오기
# df = pd.read_csv("Seq2Seq_Training_Data.csv")
df = pd.read_csv("Seq2Seq_Training_Data_CorrectionOnly.csv")
dataset = Dataset.from_pandas(df)

# %%
from transformers import AutoTokenizer,  AutoModelForSeq2SeqLM, Seq2SeqTrainer, Seq2SeqTrainingArguments, DataCollatorForSeq2Seq

model_name = "t5-small"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

def preprocess(example):
    model_inputs = tokenizer(example["input"], max_length=32, truncation=True, padding="max_length")
    labels = tokenizer(example["target"], max_length=32, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(preprocess, remove_columns=dataset.column_names)
# Out:
# Map: 100%|██████████| 332/332 [00:00<00:00, 7537.55 examples/s]

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce GTX 970

# %%
from transformers import TrainerCallback, TrainerControl, TrainerState, TrainingArguments

class SaveEveryNEpochsCallback(TrainerCallback):
    def __init__(self, model, tokenizer, n=5):
        self.n = n
        self.model = model
        self.tokenizer = tokenizer

    def on_epoch_end(self, args, state, control, **kwargs):
        if int(state.epoch) % self.n == 0:
            output_dir = os.path.join(args.output_dir, f"checkpoint-epoch-{int(state.epoch)}")
            self.model.save_pretrained(output_dir)
            self.tokenizer.save_pretrained(output_dir)
            print(f"✅ Model saved at {output_dir}")

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="./ocr_seq2seq_model_correctiononly",
    eval_strategy="epoch",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    learning_rate=2e-5,
    num_train_epochs=50,
    logging_dir="./logs",
    logging_strategy="epoch",
    save_strategy="no",
    predict_with_generate=True,
    fp16=torch.cuda.is_available(),
)

data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)


class PredictionPrinterCallback(TrainerCallback):
    def __init__(self, tokenizer, model):
        self.tokenizer = tokenizer
        self.model = model

    def on_epoch_end(self, args, state: TrainerState, control: TrainerControl, **kwargs):
        examples = ["APO", "KPIC", "102", "L102", "CJ1", "I5S", "G2I"]
        inputs = tokenizer(examples, return_tensors="pt", padding=True).input_ids.to(model.device)
        outputs = model.generate(inputs)
        decoded_preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
        for i, pred in enumerate(decoded_preds):
          if pred.strip() == "":
            print(f"❌ Input: {examples[i]} → No output generated.")
          else:
            print(f"✅ Input: {examples[i]} → Output: {pred}")

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    eval_dataset = tokenized_dataset.select(range(100)),
    train_dataset = tokenized_dataset.select(range(100, len(tokenized_dataset))),
    tokenizer=tokenizer,
    data_collator=data_collator,
    callbacks=[PredictionPrinterCallback(model=model, tokenizer=tokenizer), 
              SaveEveryNEpochsCallback(model=model, tokenizer = tokenizer, n=5)
              ]
)

trainer.train(resume_from_checkpoint=False)

model.save_pretrained("./ocr_seq2seq_model_correctiononly")
tokenizer.save_pretrained("./ocr_seq2seq_model_correctiononly")
# Out:
# C:\Users\dwdw7\AppData\Local\Temp\ipykernel_18528\3995940998.py:34: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#     <div>
#
#       <progress value='750' max='750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [750/750 02:22, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.643800</td>
#       <td>0.484832</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.611300</td>
#       <td>0.456682</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.582000</td>
#       <td>0.429318</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.532600</td>
#       <td>0.405819</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.532400</td>
#       <td>0.388739</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.500700</td>
#       <td>0.378689</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.471800</td>
#       <td>0.370893</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.464700</td>
#       <td>0.362729</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.449800</td>
#       <td>0.355394</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.439600</td>
#       <td>0.350513</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.427100</td>
#       <td>0.346792</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.425500</td>
#       <td>0.344594</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.422800</td>
#       <td>0.341172</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.406400</td>
#       <td>0.338042</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.401600</td>
#       <td>0.335301</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.391400</td>
#       <td>0.332802</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.392900</td>
#       <td>0.330274</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.385100</td>
#       <td>0.327839</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.388600</td>
#       <td>0.325786</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.377300</td>
#       <td>0.323669</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.383700</td>
#       <td>0.322035</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.375600</td>
#       <td>0.320295</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.370300</td>
#       <td>0.318431</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.360800</td>
#       <td>0.316538</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.374400</td>
#       <td>0.314598</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.368300</td>
#       <td>0.312620</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.364700</td>
#       <td>0.310994</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.358600</td>
#       <td>0.309628</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.364500</td>
#       <td>0.308256</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.362000</td>
#       <td>0.306882</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.353300</td>
#       <td>0.305620</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.355800</td>
#       <td>0.304492</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.349800</td>
#       <td>0.303641</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.355300</td>
#       <td>0.302891</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.345100</td>
#       <td>0.301983</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.355500</td>
#       <td>0.300996</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.351500</td>
#       <td>0.300175</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.345700</td>
#       <td>0.299342</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.352500</td>
#       <td>0.298624</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.345700</td>
#       <td>0.298028</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.345300</td>
#       <td>0.297492</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.345100</td>
#       <td>0.297090</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.342000</td>
#       <td>0.296590</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.338300</td>
#       <td>0.296255</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.342700</td>
#       <td>0.295962</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.353600</td>
#       <td>0.295728</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.337200</td>
#       <td>0.295571</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.344500</td>
#       <td>0.295466</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.346400</td>
#       <td>0.295389</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.345200</td>
#       <td>0.295352</td>
#     </tr>
#   </tbody>
# </table><p>
# ✅ Input: APO → Output: AU
# ❌ Input: KPIC → No output generated.
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: 0
# ❌ Input: CJ1 → No output generated.
# ✅ Input: I5S → Output: I5S
# ❌ Input: G2I → No output generated.
# ✅ Input: APO → Output: AU
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ❌ Input: CJ1 → No output generated.
# ✅ Input: I5S → Output: 0
# ❌ Input: G2I → No output generated.
# ✅ Input: APO → Output: AAP
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ❌ Input: L102 → No output generated.
# ❌ Input: CJ1 → No output generated.
# ❌ Input: I5S → No output generated.
# ❌ Input: G2I → No output generated.
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ❌ Input: L102 → No output generated.
# ✅ Input: CJ1 → Output: CCJ
# ✅ Input: I5S → Output: I5S
# ❌ Input: G2I → No output generated.
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CC1
# ✅ Input: I5S → Output: I5
# ✅ Input: G2I → Output: X2
# ✅ Model saved at ./ocr_seq2seq_model_correctiononly\checkpoint-epoch-5
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPI
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: 0
# ✅ Input: CJ1 → Output: J1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: DG
# ✅ Input: APO → Output: PO
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: M102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: 7
# ✅ Input: G2I → Output: XI
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: CPI
# ❌ Input: 102 → No output generated.
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2I
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: 102
# ✅ Input: CJ1 → Output: MJ
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2I
# ✅ Input: APO → Output: DG
# ✅ Input: KPIC → Output: KPI
# ✅ Input: 102 → Output: 0
# ✅ Input: L102 → Output: SR
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2I
# ✅ Model saved at ./ocr_seq2seq_model_correctiononly\checkpoint-epoch-10
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: Y
# ✅ Input: CJ1 → Output: CJ
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2I
# ❌ Input: APO → No output generated.
# ✅ Input: KPIC → Output: KPIC
# ❌ Input: 102 → No output generated.
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: J1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: DG2
# ✅ Input: APO → Output: AP
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: 0
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPI
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2I
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output:  MCC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: Y1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: GSI
# ✅ Model saved at ./ocr_seq2seq_model_correctiononly\checkpoint-epoch-15
# ✅ Input: APO → Output: OPO
# ✅ Input: KPIC → Output: CC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: Y
# ✅ Input: CJ1 → Output: JO
# ✅ Input: I5S → Output: I5
# ✅ Input: G2I → Output: 0
# ✅ Input: APO → Output: AP
# ✅ Input: KPIC → Output: KPI
# ❌ Input: 102 → No output generated.
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: EG
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPIK
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CC
# ✅ Input: I5S → Output: I5
# ✅ Input: G2I → Output: G2
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: XI
# ✅ Input: G2I → Output: G2I
# ✅ Input: APO → Output: O
# ✅ Input: KPIC → Output: PI
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2I
# ✅ Model saved at ./ocr_seq2seq_model_correctiononly\checkpoint-epoch-20
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: Y102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2I
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPI
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: DG2
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: CC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: 102
# ✅ Input: CJ1 → Output: CC
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: X
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPI
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ❌ Input: CJ1 → No output generated.
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: 0
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: CPI
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: X5
# ✅ Input: G2I → Output: G2
# ✅ Model saved at ./ocr_seq2seq_model_correctiononly\checkpoint-epoch-25
# ✅ Input: APO → Output: HM
# ✅ Input: KPIC → Output: CI
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5
# ✅ Input: G2I → Output: G2
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: X
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: ICPC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L2
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2I
# ✅ Input: APO → Output: APA
# ✅ Input: KPIC → Output: PIC
# ✅ Input: 102 → Output: 102
# ❌ Input: L102 → No output generated.
# ✅ Input: CJ1 → Output: CJ
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2
# ✅ Input: APO → Output: JA
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2
# ✅ Model saved at ./ocr_seq2seq_model_correctiononly\checkpoint-epoch-30
# ✅ Input: APO → Output: OPS
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: Y
# ✅ Input: APO → Output: AP
# ✅ Input: KPIC → Output: KP
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPI
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5
# ✅ Input: G2I → Output: G2I
# ✅ Input: APO → Output: OPO
# ✅ Input: KPIC → Output: KPI
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: GS2I
# ✅ Input: APO → Output: AP
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: LS100
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5
# ✅ Input: G2I → Output: G2
# ✅ Model saved at ./ocr_seq2seq_model_correctiononly\checkpoint-epoch-35
# ✅ Input: APO → Output: APO
# ❌ Input: KPIC → No output generated.
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: XX
# ✅ Input: G2I → Output: G2
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: IC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: MM
# ✅ Input: APO → Output: AP
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: SR
# ✅ Input: G2I → Output: DG
# ✅ Input: APO → Output: OE
# ✅ Input: KPIC → Output: PK
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: S10
# ✅ Input: CJ1 → Output: CJ
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2
# ✅ Input: APO → Output: Y
# ✅ Input: KPIC → Output: CC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: J1
# ✅ Input: I5S → Output: XX
# ✅ Input: G2I → Output: G2
# ✅ Model saved at ./ocr_seq2seq_model_correctiononly\checkpoint-epoch-40
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: ICZ
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: XS
# ✅ Input: G2I → Output: HG2
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: 0
# ✅ Input: CJ1 → Output: CJ
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: GC
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPI
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2I
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPI
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: Y2
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: PIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L10
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: DG
# ✅ Model saved at ./ocr_seq2seq_model_correctiononly\checkpoint-epoch-45
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: PIC
# ✅ Input: 102 → Output: M
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: X
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: CIP
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: SS
# ✅ Input: G2I → Output: G2I
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: CIP
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L2
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5
# ✅ Input: G2I → Output: G2I
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: CPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: L102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: I5S
# ✅ Input: G2I → Output: G2
# ✅ Input: APO → Output: APO
# ✅ Input: KPIC → Output: KPIC
# ✅ Input: 102 → Output: 102
# ✅ Input: L102 → Output: 102
# ✅ Input: CJ1 → Output: CJ1
# ✅ Input: I5S → Output: X
# ✅ Input: G2I → Output: G2I
# ✅ Model saved at ./ocr_seq2seq_model_correctiononly\checkpoint-epoch-50
# ('./ocr_seq2seq_model_correctiononly\\tokenizer_config.json',
#  './ocr_seq2seq_model_correctiononly\\special_tokens_map.json',
#  './ocr_seq2seq_model_correctiononly\\tokenizer.json')
